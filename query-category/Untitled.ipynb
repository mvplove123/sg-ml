# %%
import pandas as pd

# %%
rank_columns = ['pname','pdataid','pcity','pcategory','ptagScore','ptag','psum','prank','cname','cdataid','ccity','ccategory','ctagScore','ctag','csum','crank']

# %%
structureInfo= pd.read_csv('D:\\projectlist\\rank\structureRankCompare',sep='\t',encoding='gb18030',names=rank_columns)

# %%
compare = structureInfo.loc[(structureInfo.prank<structureInfo.crank) & (structureInfo.pcategory==structureInfo.ccategory),['pdataid','pname','pcity','pcategory','ptagScore','ptag','prank','cdataid','cname','ccategory','ctagScore','ctag','crank','psum','csum']]

# %%
compare
# Out:
#                        pdataid                 pname      pcity pcategory  \
# 39            1_D1000507463314                  五金水暖        西宁市      购物场所
# 40            1_D1000507463314                  五金水暖        西宁市      购物场所
# 251           1_D1000055403488         中国联通(汽车东站营业厅)        兰州市      购物场所
# 715        1_D_01_aeEVBffEfAb2             遂川县汤湖采育林场        吉安市      公司企业
# 716           1_D1000428224191             苍溪县房地产管理局        广元市      政府机关
# 1386          1_D1000535641148           申通快递(上海航空部)        上海市      公司企业
# 1592          1_D1000439808935            朝阳家具(皖潜大道)        安庆市      购物场所
# 1593          1_D1000504222468              中国铁建电气化局        南宁市      公司企业
# 1709          1_D1000141878941                鸿源汽车中介        德阳市      公司企业
# 1713          1_D1000491593613      浪漫假期国际旅行社(盘山营业部)        盘锦市      公司企业
# 1900       1_D_02_3mIZ3uQZjye2                 上海新天地        上海市       房地产
# 2166          1_D1000450813770            中国联通(新华东街)      呼和浩特市      购物场所
# ...

# %%
rt =compare.groupby(['pname']).pcategory.count().sort_values()

# %%
# %matplotlib inline
from matplotlib.font_manager import FontProperties 
import matplotlib.pyplot as plt

# %%
font = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=14)

# %%
plt.plot(rt.values)
plt.xlabel(rt.index.values,fontproperties='SimHei')
plt.bar
# Out:
# <function matplotlib.pyplot.bar>

# %%
plt.plot(rt)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-307-2d083441e540> in <module>()
# ----> 1 plt.plot(rt)
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3316                       mplDeprecation)
#    3317     try:
# -> 3318         ret = ax.plot(*args, **kwargs)
#    3319     finally:
#    3320         ax._hold = washold
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1889                     warnings.warn(msg % (label_namer, func.__name__),
#    1890                                   RuntimeWarning, stacklevel=2)
# -> 1891             return func(ax, *args, **kwargs)
#    1892         pre_doc = inner.__doc__
#    1893         if pre_doc is None:
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, *args, **kwargs)
#    1405
# ...

# %%
compare
# Out:
#                            pname pcategory  ptagScore  prank  \
# 314                  大运河森林公园(东园)      旅游景点          3      3
# 372               清华园街道食品药品安全委员会      政府机关          1      2
# 577                 北大荒绿色食品(中石路)      购物场所          1      2
# 692                       陶然居写字楼      汽车服务          0      1
# 693                       陶然居写字楼      汽车服务          0      1
# 694                       陶然居写字楼      汽车服务          0      1
# 1088                   常青园(常青园路)       房地产          4      4
# 1183         中国农业大学东校区-水利与土木工程学院      学校科研          3      2
# 2052                  华北电力大学研究生院      学校科研          3      2
# 2201                    北京文理研修学院      学校科研          3      2
# 2437    北京市东城区人力资源和社会保障局(交道口南大街)      政府机关          2      3
# 3337                       中关村学院      学校科研          0      3
# 3339                       中关村学院      学校科研          0      3
# 3694                 滨河居住区临镜苑7号楼       房地产          1      1
# ...

# %%
pd.reset_option('max_rows')

# %%
structureInfo.loc[(structureInfo.prank<structureInfo.crank) & (structureInfo.pcategory==structureInfo.ccategory),['pname','pcategory','ptagScore','prank','cname','ccategory','ctagScore','crank']]
# Out:
#                              pname pcategory  ptagScore  prank  \
# 314                    大运河森林公园(东园)      旅游景点          3      3
# 372                 清华园街道食品药品安全委员会      政府机关          1      2
# 577                   北大荒绿色食品(中石路)      购物场所          1      2
# 692                         陶然居写字楼      汽车服务          0      1
# 693                         陶然居写字楼      汽车服务          0      1
# 694                         陶然居写字楼      汽车服务          0      1
# 1088                     常青园(常青园路)       房地产          4      4
# 1183           中国农业大学东校区-水利与土木工程学院      学校科研          3      2
# 2052                    华北电力大学研究生院      学校科研          3      2
# 2201                      北京文理研修学院      学校科研          3      2
# 2437      北京市东城区人力资源和社会保障局(交道口南大街)      政府机关          2      3
# 3337                         中关村学院      学校科研          0      3
# 3339                         中关村学院      学校科研          0      3
# 3694                   滨河居住区临镜苑7号楼       房地产          1      1
# ...

# %%
structureInfo[structureInfo.pname=='启迪科技大厦']
# Out:
#          pname           pdataid pcity pcategory  ptagScore  \
# 202533  启迪科技大厦  1_D1000501808418   北京市       房地产          2
# 202534  启迪科技大厦  1_D1000501808418   北京市       房地产          2
# 202535  启迪科技大厦  1_D1000501808418   北京市       房地产          2
# 202536  启迪科技大厦  1_D1000501808418   北京市       房地产          2
# 202537  启迪科技大厦  1_D1000501808418   北京市       房地产          2
# 202538  启迪科技大厦  1_D1000501808418   北京市       房地产          2
# 202539  启迪科技大厦  1_D1000501808418   北京市       房地产          2
#
#                                                      ptag  psum  prank  \
# 202533  $$NEWMANUAL_M1$$$$DFB:地产小区-楼宇-写字楼$$,$$GAODE:商务...   1.1      2
# 202534  $$NEWMANUAL_M1$$$$DFB:地产小区-楼宇-写字楼$$,$$GAODE:商务...   1.1      2
# 202535  $$NEWMANUAL_M1$$$$DFB:地产小区-楼宇-写字楼$$,$$GAODE:商务...   1.1      2
# 202536  $$NEWMANUAL_M1$$$$DFB:地产小区-楼宇-写字楼$$,$$GAODE:商务...   1.1      2
# 202537  $$NEWMANUAL_M1$$$$DFB:地产小区-楼宇-写字楼$$,$$GAODE:商务...   1.1      2
# ...

# %%
compare
# Out:
#                            pname pcategory  ptagScore  prank  \
# 372               清华园街道食品药品安全委员会      政府机关          1      2
# 577                 北大荒绿色食品(中石路)      购物场所          1      2
# 692                       陶然居写字楼      汽车服务          0      1
# 693                       陶然居写字楼      汽车服务          0      1
# 694                       陶然居写字楼      汽车服务          0      1
# 2052                  华北电力大学研究生院      学校科研          3      2
# 2201                    北京文理研修学院      学校科研          3      2
# 2437    北京市东城区人力资源和社会保障局(交道口南大街)      政府机关          2      3
# 3337                       中关村学院      学校科研          0      3
# 3339                       中关村学院      学校科研          0      3
# 4241                    北京农业职业学院      学校科研          3      4
# 4393               中国联通(北苑东路营业厅)      邮政电信          0      2
# 4863                      贡院西街7号       房地产          0      2
# 4905                   北京南苑机场航站楼      交通出行          0      3
# ...

# %%
# %matplotlib inline

# %%
report.rename(columns={'test_report:':'category'},inplace=True)

# %%
report.loc[(report.precision>=0.9) & (report.recall>0.8),:]
# Out:
#    category  precision  recall  f1-score  support
# 1      餐饮美食       0.91    0.81      0.86   848433
# 8      教育文化       0.99    0.98      0.98   178862
# 10     金融银行       0.91    0.81      0.86   512019
# 11     景点游玩       0.94    0.91      0.93   445851
# 15    农林牧渔业       0.90    0.91      0.90   253718
# 16     批发零售       0.94    0.93      0.94   263996

# %%
report.rename(columns={'test_report:':'category'},inplace=True)

# %%
report
# Out:
#      category  precision  recall  f1-score  support
# 0          餐饮       0.89    0.91      0.90   159883
# 1        餐饮美食       0.91    0.81      0.86   848433
# 2          地名       0.71    0.78      0.74    26867
# 3        公共设施       0.75    0.99      0.85  1217769
# 4        公司企业       0.84    0.75      0.79   212439
# 5          购物       0.86    0.81      0.83   806331
# 6        交通运输       0.89    0.82      0.85  1949891
# 7        教育培训       0.94    0.63      0.75    63146
# 8        教育文化       0.99    0.98      0.98   178862
# 9        金融保险       0.65    0.46      0.54    62261
# 10       金融银行       0.91    0.81      0.86   512019
# 11       景点游玩       0.94    0.91      0.93   445851
# 12       酒店住宿       0.76    0.75      0.76    37593
# 13       居民服务       0.57    0.70      0.63     5850
# 14       科研机构       0.87    0.83      0.85   150319
# 15      农林牧渔业       0.90    0.91      0.90   253718
# 16       批发零售       0.94    0.93      0.94   263996
# ...

# %%
report.columns=report.columns.str.replace('-','')

# %%
df=report.iloc[0:19,:].sort_values(['precision','recall'],ascending=False)

# %%
df.index = [i for i in range(len(df))]

# %%
data=[[1.2949355699E7,4837170.296],[1.2949373535E7,4837079.102],[1.2949283443E7,4837076.331],[1.2949312251E7,4837088.155],[1.294931125E7,4837109.576],[1.2949310133E7,4837173.266],[1.2950287043E7,4838009.815]]

# %%
point = pd.DataFrame(data,columns=['x','y'])

# %%
# %matplotlib inline

# %%
point.y
# Out:
# 0    4837170.296
# 1    4837079.102
# 2    4837076.331
# 3    4837088.155
# 4    4837109.576
# 5    4837173.266
# 6    4838009.815
# Name: y, dtype: float64

# %%
rank = pd.read_csv('D:\\structure\\rank\\beijingshi-fangdichan-feature-rank',sep='\t',encoding='gb18030')

# %%
rank.loc[rank.dataId.isin(['1_D1000501808418','1_09001923466','1_D1000055271333','1_09001923465','1_D1000507571160']),['name','dataId','areaScore','area','rank','sumWeight']]
# Out:
#                name            dataId  areaScore    area  rank  sumWeight
# 176780  启迪科技大厦B座-西门  1_D1000507571160          0       0     1       0.30
# 192072     启迪科技大厦A座     1_09001923465          2    2050     3       2.00
# 192140     启迪科技大厦C座     1_09001923466          2    1504     3       2.15
# 195602     启迪科技大厦D座  1_D1000055271333          1      50     3       1.70
# 208134       启迪科技大厦  1_D1000501808418          5  936844     3       1.85

# %%
rank[rank.dataId=='1_09001923466']
# Out:
# Index(['name', 'dataId', 'city', 'parentCategory', 'subCategory', 'brand',
#        'categoryScore', 'tagScore', 'matchCountScore', 'gradeScore',
#        'commentScore', 'priceScore', 'areaScore', 'leafCountScore',
#        'doorCountScore', 'parkCountScore', 'innerCountScore',
#        'buildCountScore', 'point', 'keyword', 'matchCount', 'grade', 'comment',
#        'price', 'area', 'leafCount', 'doorCount', 'parkCount', 'innerCount',
#        'buildCount', 'hotCount', 'hitcount', 'viewcount', 'sumViewOrder',
#        'sumWeight', 'label', 'rank'],
#       dtype='object')

# %%
rank[rank.dataId.isin(['1_09001923466','1_D1000501808418','1_09001923465'])].T
# Out:
#                                                             192072  \
# name                                                      启迪科技大厦A座
# dataId                                               1_09001923465
# city                                                           北京市
# parentCategory                                                 房地产
# subCategory                                                    写字楼
# brand
# categoryScore                                                    4
# tagScore                                                         4
# matchCountScore                                                  0
# gradeScore                                                       0
# commentScore                                                     0
# priceScore                                                       0
# areaScore                                                        2
# leafCountScore                                                   3
# ...

# %%
rank.memory_usage(deep=True)
# Out:
# Index                    80
# name               21024521
# dataId             15227066
# city               18321160
# parentCategory     18321160
# subCategory        17973944
# brand              12078970
# categoryScore       1665560
# tagScore            1665560
# matchCountScore     1665560
# gradeScore          1665560
# commentScore        1665560
# priceScore          1665560
# areaScore           1665560
# leafCountScore      1665560
# doorCountScore      1665560
# parkCountScore      1665560
# innerCountScore     1665560
# buildCountScore     1665560
# point              17233706
# keyword            30984843
# matchCount          1665560
# grade               1665560
# comment             1665560
# price               1665560
# area                1665560
# leafCount           1665560
# doorCount           1665560
# parkCount           1665560
# innerCount          1665560
# buildCount          1665560
# hotCount            1665560
# hitcount            1665560
# ...
